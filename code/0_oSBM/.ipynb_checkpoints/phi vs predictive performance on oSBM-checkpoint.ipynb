# %% [markdown]
# 12/8/2017
#
# # Summary
# Goal of this notebook is to compare the predictive performance of oSBM as we vary \phi -- without any block structure.

# %%
from __future__ import division
import os
import igraph
import numpy as np
import pandas as pd
from matplotlib.backends.backend_pdf import PdfPages
from scipy.stats.kde import gaussian_kde
from matplotlib.ticker import FixedLocator,LinearLocator,MultipleLocator, FormatStrFormatter
from mpl_toolkits.axes_grid1 import Grid

# relevant python libraries
execfile('../functions/python_libraries.py')

# oSBM code
execfile('../functions/create_oSBM_class_specific_alternative.py')

# compute homophily + monophily
execfile('../functions/compute_homophily.py')
execfile('../functions/compute_homophily_p_value.py')
execfile('../functions/compute_monophily.py')
execfile('../functions/compute_chi_square.py')



# code for attribute prediction
execfile('../functions/benchmark_classifier.py')
execfile('../functions/LINK_finalized.py')
execfile('../functions/majority_vote.py')
execfile('../functions/ZGL.py')

# %% [markdown]
# ## Vary \phi on oSBM without block structure

# %%
percent_initially_unlabelled = [0.99, 0.9, 0.5, 0.1]
percent_initially_labelled = np.subtract(1, percent_initially_unlabelled)
percent_initially_labelled
# Out:
# array([ 0.01,  0.1 ,  0.5 ,  0.9 ])

# %%
disp_oSBM_array = np.linspace(0,0.004,20)

# %% [markdown]
# ### descriptive spot-checks

# %%
monophily_record_0 = []
monophily_record_1 = []

homophily_pvalue_0 = []
homophily_pvalue_1 = []

for j in range(len(disp_oSBM_array)):
    print j
    ## create 1 realization from oSBM
    (adj_noByesO_osbm, y_noByesO_osbm) = create_affiliation_model_temp(84,
                                  lambda_block_parameter =1,
                                           dispersion_parameter_vect = np.array([np.array([disp_oSBM_array[j], disp_oSBM_array[j]]),
                                            np.array([disp_oSBM_array[j], disp_oSBM_array[j]])]),
                                  class_size_vect = np.array([1000,1000]))
    
    h_p =  homophily_intercept_p_value(adj_noByesO_osbm,
                         y_noByesO_osbm)
    homophily_pvalue_0.append(h_p[0])
    homophily_pvalue_1.append(h_p[1])


    m = monophily_index_overdispersion_Williams(adj_noByesO_osbm,
                                       y_noByesO_osbm)
    monophily_record_0.append(m[0])
    monophily_record_1.append(m[1])
    print 'check monophily p-value: '
    print compute_chi_square_statistic(adj_noByesO_osbm, y_noByesO_osbm)
    print ''
# Out:
# 0
# p_in:  0.042
# p_out:  0.042
#
# spot-check average degree:
# 84.1045
#
# spot-check homophily:
# [0.50027394649705814, 0.50201184555672929]
#
# spot-check monophily:
# [0.0, 0.0]
#
# check monophily p-value:
# [0.95078491087860395, 0.97470294685179226]
#
# 1
# p_in:  0.042
# p_out:  0.042
#
# spot-check average degree:
# 83.683
#
# spot-check homophily:
# [0.50186507132557112, 0.4991432508537535]
#
# spot-check monophily:
# [0.0010134312793532987, 0.0013873946758278528]
#
# check monophily p-value:
# [0.03255567386209357, 0.0069441055802523799]
#
# 2
# p_in:  0.042
# p_out:  0.042
#
# spot-check average degree:
# 84.02
#
# spot-check homophily:
# [0.500005967085556, 0.50270039289232848]
#
# spot-check monophily:
# [0.0031092958182789322, 0.005156780540758619]
#
# check monophily p-value:
# [6.0046634997590331e-08, 0.0]
#
# 3
# p_in:  0.042
# p_out:  0.042
#
# spot-check average degree:
# 83.9005
#
# spot-check homophily:
# [0.49831871432503266, 0.50229123631787642]
#
# spot-check monophily:
# [0.0055406282463246566, 0.005195455404696569]
#
# check monophily p-value:
# [0.0, 0.0]
#
# 4
# p_in:  0.042
# p_out:  0.042
#
# spot-check average degree:
# 83.517
#
# spot-check homophily:
# [0.49544167746269369, 0.49728696067885736]
#
# spot-check monophily:
# [0.008909086415967582, 0.010379475979873704]
#
# check monophily p-value:
# [0.0, 0.0]
#
# 5
# p_in:  0.042
# p_out:  0.042
#
# spot-check average degree:
# 84.3405
#
# spot-check homophily:
# [0.49659993116789097, 0.49752422469141649]
#
# spot-check monophily:
# [0.011168994820513893, 0.011436233713581333]
#
# check monophily p-value:
# [0.0, 0.0]
#
# 6
# p_in:  0.042
# p_out:  0.042
#
# spot-check average degree:
# 84.4365
#
# spot-check homophily:
# [0.49771135761077623, 0.5015690993605626]
#
# spot-check monophily:
# [0.012797834525210387, 0.014690460080179144]
#
# check monophily p-value:
# [0.0, 0.0]
#
# 7
# p_in:  0.042
# p_out:  0.042
#
# spot-check average degree:
# 84.218
#
# spot-check homophily:
# [0.50206670467502856, 0.50237405631261578]
#
# spot-check monophily:
# [0.016528748497103164, 0.01611384433657081]
#
# check monophily p-value:
# [0.0, 0.0]
#
# 8
# p_in:  0.042
# p_out:  0.042
#
# spot-check average degree:
# 84.391
#
# spot-check homophily:
# [0.49217256214149141, 0.50065803388874519]
#
# spot-check monophily:
# [0.015754630961449283, 0.015946438591215566]
#
# check monophily p-value:
# [0.0, 0.0]
#
# 9
# p_in:  0.042
# p_out:  0.042
#
# spot-check average degree:
# 83.6415
#
# spot-check homophily:
# [0.50533023500946261, 0.50716612766566826]
#
# spot-check monophily:
# [0.019778717042228024, 0.02052677699756379]
#
# check monophily p-value:
# [0.0, 0.0]
#
# 10
# p_in:  0.042
# p_out:  0.042
#
# spot-check average degree:
# 82.6305
#
# spot-check homophily:
# [0.50926563084760901, 0.50685446692871361]
#
# spot-check monophily:
# [0.02187525970495232, 0.021193089001274222]
#
# check monophily p-value:
# [0.0, 0.0]
#
# 11
# p_in:  0.042
# p_out:  0.042
#
# spot-check average degree:
# 83.4185
#
# spot-check homophily:
# [0.50063820396282921, 0.49569920971472631]
#
# spot-check monophily:
# [0.025488482473063477, 0.028041214402277973]
#
# check monophily p-value:
# [0.0, 0.0]
#
# 12
# p_in:  0.042
# p_out:  0.042
#
# spot-check average degree:
# 83.9495
#
# spot-check homophily:
# [0.50543004265182023, 0.50834936696833655]
#
# spot-check monophily:
# [0.030364202625224757, 0.02537701744741861]
#
# check monophily p-value:
# [0.0, 0.0]
#
# 13
# p_in:  0.042
# p_out:  0.042
#
# spot-check average degree:
# 83.301
#
# spot-check homophily:
# [0.50716966833623434, 0.49334745401648222]
#
# spot-check monophily:
# [0.030637078777968573, 0.027260972091584814]
#
# check monophily p-value:
# [0.0, 0.0]
#
# 14
# p_in:  0.042
# p_out:  0.042
#
# spot-check average degree:
# 85.1855
#
# spot-check homophily:
# [0.50232683223422658, 0.49835586408476434]
#
# spot-check monophily:
# [0.03254346002826311, 0.034028293584507915]
#
# check monophily p-value:
# [0.0, 0.0]
#
# 15
# p_in:  0.042
# p_out:  0.042
#
# spot-check average degree:
# 83.925
#
# spot-check homophily:
# [0.49686970523558321, 0.505264028547459]
#
# spot-check monophily:
# [0.03275866084657413, 0.03300887460488148]
#
# check monophily p-value:
# [0.0, 0.0]
#
# 16
# p_in:  0.042
# p_out:  0.042
#
# spot-check average degree:
# 83.837
#
# spot-check homophily:
# [0.49223579984544047, 0.50445450045959128]
#
# spot-check monophily:
# [0.03741027280138124, 0.03427346768332884]
#
# check monophily p-value:
# [0.0, 0.0]
#
# 17
# p_in:  0.042
# p_out:  0.042
#
# spot-check average degree:
# 84.33
#
# spot-check homophily:
# [0.49810405696149873, 0.50051459193451076]
#
# spot-check monophily:
# [0.0380534391877434, 0.0395304188649065]
#
# check monophily p-value:
# [0.0, 0.0]
#
# 18
# p_in:  0.042
# p_out:  0.042
#
# spot-check average degree:
# 84.67
#
# spot-check homophily:
# [0.49501907587960997, 0.49198019332827903]
#
# spot-check monophily:
# [0.04412930779183489, 0.040818603873956597]
#
# check monophily p-value:
# [0.0, 0.0]
#
# 19
# p_in:  0.042
# p_out:  0.042
#
# spot-check average degree:
# 84.0475
#
# spot-check homophily:
# [0.50091107009323677, 0.4953158089950826]
#
# spot-check monophily:
# [0.04318410337848687, 0.04552840404875604]
#
# check monophily p-value:
# [0.0, 0.0]

# %%
test = [p[0] for p in homophily_pvalue_0]
print test
# Out:
# [0.8738620901340528, 0.27990949841686513, 0.99724364387770292, 0.33102624138487241, 0.0084834786878873799, 0.048389150629767522, 0.1843450728498412, 0.23039547162005417, 5.9438047293638399e-06, 0.0020688115915135441, 9.6536419545683979e-08, 0.71170937123687028, 0.0016786504240338946, 3.0865765174637847e-05, 0.17353411392665447, 0.070914511234394184, 7.8752494399197608e-06, 0.27141019413543321, 0.003695993569502867, 0.59630215210451198]

# %%
np.mean(np.array(test) < 0.05)
# Out:
# 0.45000000000000001

# %%
(adj_noByesO_osbm, y_noByesO_osbm) = create_affiliation_model_temp(84,
                                  lambda_block_parameter =1,
                                           dispersion_parameter_vect = np.array([np.array([disp_oSBM_array[j], disp_oSBM_array[j]]),
                                            np.array([disp_oSBM_array[j], disp_oSBM_array[j]])]),
                                  class_size_vect = np.array([1000,1000]))
    
h_p =  homophily_intercept_p_value(adj_noByesO_osbm,
                         y_noByesO_osbm)
print h_p

# %%
#just want to spot-check increasing \phi_in, \phi_out increases our monophily measure
monophily_record_0
# Out:
# [0.0,
#  0.0011577807659964832,
#  0.004268601227213715,
#  0.007458105680490034,
#  0.008884524341685834,
#  0.01079532102644987,
#  0.014618010865699456,
#  0.014888250889734337,
#  0.0175866545057458,
#  0.022712339108206945,
#  0.02197809320996734,
#  0.023130555919028895,
#  0.026706293615608487,
#  0.0293388082620133,
#  0.02797696697270528,
#  0.03246090153412911,
#  0.03665869477282195,
#  0.038695491609142124,
#  0.040026786038139965,
#  0.045629578050958394]

# %%
## combine below into loop
MV1_results = []
MV2_results = []
MV1_se_results = []
MV2_se_results = []
monophily_record_0 = []
monophily_record_1 = []


for j in range(len(disp_oSBM_array)):
    print j
    ## create 1 realization from oSBM
    (adj_noByesO_osbm, y_noByesO_osbm) = create_affiliation_model_temp(84,
                                  lambda_block_parameter =1,
                                           dispersion_parameter_vect = np.array([np.array([disp_oSBM_array[j], disp_oSBM_array[j]]),
                                            np.array([disp_oSBM_array[j], disp_oSBM_array[j]])]),
                                  class_size_vect = np.array([1000,1000]))
    m = monophily_index_overdispersion_Williams(adj_noByesO_osbm,
                                       y_noByesO_osbm)
    monophily_record_0.append(m[0])
    monophily_record_1.append(m[1])
    print 'check monophily p-value: '
    print compute_chi_square_statistic(adj_noByesO_osbm, y_noByesO_osbm)
    print ''
    
    ## 1-hop MV
    (mean_accuracy_mv_noByesO, se_accuracy_mv_noByesO, 
     mean_micro_auc_mv_noByesO,se_micro_auc_mv_noByesO, 
     mean_wt_auc_mv_noByesO,se_wt_auc_mv_noByesO) =majority_vote_finalized(percent_initially_unlabelled,  
                                                                    np.array(y_noByesO_osbm), 
                                                                    np.array(adj_noByesO_osbm), 
                                                                    num_iter=10) 
    MV1_results.append(mean_wt_auc_mv_noByesO)
    MV1_se_results.append(se_wt_auc_mv_noByesO)


    ## 2-hop MV
    adj_noByesO_osbm2= np.matrix(adj_noByesO_osbm)**2
    adj_noByesO_osbm2[range(adj_noByesO_osbm.shape[0]),range(adj_noByesO_osbm.shape[0])]=0

    (mean_accuracy_mv2_noByesO, se_accuracy_m2v_noByesO, 
     mean_micro_auc_mv2_noByesO,se_micro_auc_mv2_noByesO, 
     mean_wt_auc_mv2_noByesO,se_wt_auc_mv2_noByesO) =majority_vote_finalized(percent_initially_unlabelled,  
                                                                    np.array(y_noByesO_osbm), 
                                                                    np.array(adj_noByesO_osbm2), 
                                                                    num_iter=10) 
    MV2_results.append(mean_wt_auc_mv2_noByesO)
    MV2_se_results.append(se_wt_auc_mv2_noByesO)
# Out:
# 0
# p_in:  0.042
# p_out:  0.042
#
# spot-check average degree:
# 83.711
#
# spot-check homophily:
# [0.49992825541073777, 0.50089507351537133]
#
# spot-check monophily:
# [0.0, 5.439457115590194e-05]
#
# check monophily p-value:
# [0.96234526248124808, 0.45407244248567324]
#
# 0.99
# 0.9
# 0.5
# 0.1
# 0.99
# 0.9
# 0.5
# 0.1
# 1
# p_in:  0.042
# p_out:  0.042
#
# spot-check average degree:
# 84.5035
#
# spot-check homophily:
# [0.49847851569437707, 0.49903015966883502]
#
# spot-check monophily:
# [0.0015104259215850445, 0.0015986011640145327]
#
# check monophily p-value:
# [0.0033518429343212253, 0.002010950865998562]
#
# 0.99
# 0.9
# 0.5
# 0.1
# 0.99
# 0.9
# 0.5
# 0.1
# 2
# p_in:  0.042
# p_out:  0.042
#
# spot-check average degree:
# 83.3805
#
# spot-check homophily:
# [0.49893776630858794, 0.4997243726481797]
#
# spot-check monophily:
# [0.0038782411482590788, 0.0050888386209721765]
#
# check monophily p-value:
# [3.3239966334974724e-11, 0.0]
#
# 0.99
# 0.9
# 0.5
# 0.1
# 0.99
# 0.9
# 0.5
# 0.1
# 3
# p_in:  0.042
# p_out:  0.042
#
# spot-check average degree:
# 84.205
#
# spot-check homophily:
# [0.49968560547639668, 0.49868641599600583]
#
# spot-check monophily:
# [0.009151075114533372, 0.0065243563932561085]
#
# check monophily p-value:
# [0.0, 0.0]
#
# 0.99
# 0.9
# 0.5
# 0.1
# 0.99
# 0.9
# 0.5
# 0.1
# 4
# p_in:  0.042
# p_out:  0.042
#
# spot-check average degree:
# 83.8755
#
# spot-check homophily:
# [0.49793252232276625, 0.50317851890507137]
#
# spot-check monophily:
# [0.010353870177227428, 0.0096524735822993]
#
# check monophily p-value:
# [0.0, 0.0]
#
# 0.99
# 0.9
# 0.5
# 0.1
# 0.99
# 0.9
# 0.5
# 0.1
# 5
# p_in:  0.042
# p_out:  0.042
#
# spot-check average degree:
# 83.796
#
# spot-check homophily:
# [0.49746357258499729, 0.50236916170864654]
#
# spot-check monophily:
# [0.010500548494881122, 0.012515740812826383]
#
# check monophily p-value:
# [0.0, 0.0]
#
# 0.99
# 0.9
# 0.5
# 0.1
# 0.99
# 0.9
# 0.5
# 0.1
# 6
# p_in:  0.042
# p_out:  0.042
#
# spot-check average degree:
# 83.434
#
# spot-check homophily:
# [0.5005691417342647, 0.50026975506240323]
#
# spot-check monophily:
# [0.014279949365128324, 0.011985804263495783]
#
# check monophily p-value:
# [0.0, 0.0]
#
# 0.99
# 0.9
# 0.5
# 0.1
# 0.99
# 0.9
# 0.5
# 0.1
# 7
# p_in:  0.042
# p_out:  0.042
#
# spot-check average degree:
# 84.5225
#
# spot-check homophily:
# [0.50666115995043948, 0.50405693950177932]
#
# spot-check monophily:
# [0.017086569865816647, 0.017660669994352764]
#
# check monophily p-value:
# [0.0, 0.0]
#
# 0.99
# 0.9
# 0.5
# 0.1
# 0.99
# 0.9
# 0.5
# 0.1
# 8
# p_in:  0.042
# p_out:  0.042
#
# spot-check average degree:
# 83.0505
#
# spot-check homophily:
# [0.49992168391628611, 0.50056555641124367]
#
# spot-check monophily:
# [0.021141543120282952, 0.017393329024462438]
#
# check monophily p-value:
# [0.0, 0.0]
#
# 0.99
# 0.9
# 0.5
# 0.1
# 0.99
# 0.9
# 0.5
# 0.1
# 9
# p_in:  0.042
# p_out:  0.042
#
# spot-check average degree:
# 82.636
#
# spot-check homophily:
# [0.50812978754155225, 0.50344098049705754]
#
# spot-check monophily:
# [0.02099788361833915, 0.021698185346688124]
#
# check monophily p-value:
# [0.0, 0.0]
#
# 0.99
# 0.9
# 0.5
# 0.1
# 0.99
# 0.9
# 0.5
# 0.1
# 10
# p_in:  0.042
# p_out:  0.042
#
# spot-check average degree:
# 85.3455
#
# spot-check homophily:
# [0.50038926782788551, 0.49196521410341243]
#
# spot-check monophily:
# [0.020781389493953726, 0.023740730187822672]
#
# check monophily p-value:
# [0.0, 0.0]
#
# 0.99
# 0.9
# 0.5
# 0.1
# 0.99
# 0.9
# 0.5
# 0.1
# 11
# p_in:  0.042
# p_out:  0.042
#
# spot-check average degree:
# 83.123
#
# spot-check homophily:
# [0.50618678071166001, 0.50477085441665459]
#
# spot-check monophily:
# [0.024822655951223547, 0.026004608519484915]
#
# check monophily p-value:
# [0.0, 0.0]
#
# 0.99
# 0.9
# 0.5
# 0.1
# 0.99
# 0.9
# 0.5
# 0.1
# 12
# p_in:  0.042
# p_out:  0.042
#
# spot-check average degree:
# 83.9645
#
# spot-check homophily:
# [0.50463150375044652, 0.50433052573892945]
#
# spot-check monophily:
# [0.029097573768302937, 0.026615111754536725]
#
# check monophily p-value:
# [0.0, 0.0]
#
# 0.99
# 0.9
# 0.5
# 0.1
# 0.99
# 0.9
# 0.5
# 0.1
# 13
# p_in:  0.042
# p_out:  0.042
#
# spot-check average degree:
# 84.075
#
# spot-check homophily:
# [0.50408430578709207, 0.50520375430676012]
#
# spot-check monophily:
# [0.03028450406722063, 0.029808559798700864]
#
# check monophily p-value:
# [0.0, 0.0]
#
# 0.99
# 0.9
# 0.5
# 0.1
# 0.99
# 0.9
# 0.5
# 0.1
# 14
# p_in:  0.042
# p_out:  0.042
#
# spot-check average degree:
# 83.7395
#
# spot-check homophily:
# [0.49357162615608496, 0.50068775790921594]
#
# spot-check monophily:
# [0.031018704635376655, 0.031627064684008756]
#
# check monophily p-value:
# [0.0, 0.0]
#
# 0.99
# 0.9
# 0.5
# 0.1
# 0.99
# 0.9
# 0.5
# 0.1
# 15
# p_in:  0.042
# p_out:  0.042
#
# spot-check average degree:
# 83.406
#
# spot-check homophily:
# [0.5027220630372492, 0.49848287819679232]
#
# spot-check monophily:
# [0.03379475713069204, 0.0326647115086241]
#
# check monophily p-value:
# [0.0, 0.0]
#
# 0.99
# 0.9
# 0.5
# 0.1
# 0.99
# 0.9
# 0.5
# 0.1
# 16
# p_in:  0.042
# p_out:  0.042
#
# spot-check average degree:
# 83.21
#
# spot-check homophily:
# [0.5075516504393256, 0.4954501216545012]
#
# spot-check monophily:
# [0.038744199149567456, 0.036856587491518995]
#
# check monophily p-value:
# [0.0, 0.0]
#
# 0.99
# 0.9
# 0.5
# 0.1
# 0.99
# 0.9
# 0.5
# 0.1
# 17
# p_in:  0.042
# p_out:  0.042
#
# spot-check average degree:
# 83.821
#
# spot-check homophily:
# [0.5058126363733918, 0.50524632041349837]
#
# spot-check monophily:
# [0.040497682672480745, 0.038628517270463465]
#
# check monophily p-value:
# [0.0, 0.0]
#
# 0.99
# 0.9
# 0.5
# 0.1
# 0.99
# 0.9
# 0.5
# 0.1
# 18
# p_in:  0.042
# p_out:  0.042
#
# spot-check average degree:
# 83.214
#
# spot-check homophily:
# [0.50443257064974856, 0.50805206001029701]
#
# spot-check monophily:
# [0.043784375961673144, 0.03780507800370695]
#
# check monophily p-value:
# [0.0, 0.0]
#
# 0.99
# 0.9
# 0.5
# 0.1
# 0.99
# 0.9
# 0.5
# 0.1
# 19
# p_in:  0.042
# p_out:  0.042
#
# spot-check average degree:
# 84.387
#
# spot-check homophily:
# [0.5026799976335562, 0.50116901458597896]
#
# spot-check monophily:
# [0.044233241817643106, 0.042239172221955626]
#
# check monophily p-value:
# [0.0, 0.0]
#
# 0.99
# 0.9
# 0.5
# 0.1
# 0.99
# 0.9
# 0.5
# 0.1
# /Users/kristen/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:44: RuntimeWarning: invalid value encountered in true_divide

# %%
dir_osbm = '/Users/kristen/Dropbox/gender_graph_data/manuscript/nature_hb/gender_graph_final_code_NatureHB/figures/'

# %%
for i in range(len(percent_initially_unlabelled)):
    # %matplotlib inline
    plt.scatter(disp_oSBM_array,
               [j[i] for j in MV1_results], color = 'red')
    plt.text(0.000001,0.95,'1hop MV', color = 'red')
    plt.text(0.000001,0.91,'2hop MV', color = 'maroon')


    plt.scatter(disp_oSBM_array,
               [j[i] for j in MV2_results], color = 'maroon') 
    plt.xlabel('dispersion')
    plt.ylabel('AUC')
    plt.ylim(0,1.01)
    plt.xlim(np.min(disp_oSBM_array)-0.0001,np.max(disp_oSBM_array)+0.0001)
    plt.title('% initially labeled: '+np.str(np.int(percent_initially_labelled[i] * 100))+', oSBM')
    plt.tight_layout()
    pp = PdfPages(dir_osbm +np.str(percent_initially_labelled[i] * 100) + '_initially_labeled.pdf')
    pp.savefig()
    pp.close()
    #plt.show()

# %%
for i in range(len(percent_initially_unlabelled)):
    # %matplotlib inline
    plt.errorbar(disp_oSBM_array,
               [j[i] for j in MV1_results],
                 yerr=[j[i] for j in MV1_se_results], 
                 fmt='--o', capthick=2,
            #alpha=0.6, 
                 elinewidth=3, color = 'red')
    plt.text(0.000001,0.95,'1hop MV', color = 'red')
    plt.text(0.000001,0.91,'2hop MV', color = 'maroon')


    plt.errorbar(disp_oSBM_array,
               [j[i] for j in MV2_results], 
                 yerr=[j[i] for j in MV2_se_results], 
                 fmt='--o', capthick=2,
            #alpha=0.6, 
                 elinewidth=3,color = 'maroon') 
    #plt.xlabel('dispersion')
    #plt.xlabel('$\phi^*_{in}$, $\phi^*_{out}$')
    plt.xlabel('overdispersion')
    plt.ylabel('AUC')
    plt.ylim(0,1.01)
    plt.xlim(np.min(disp_oSBM_array)-0.0001,np.max(disp_oSBM_array)+0.0001)
    #plt.set_spines["right"].set_visible(False)
    #plt.set_spines["top"].set_visible(False)
    plt.title(np.str((percent_initially_labelled[i] * 100)) + '% initially labeled')
    plt.tight_layout()
    pp = PdfPages(dir_osbm +np.str((percent_initially_labelled[i] * 100)) + '_with_bars_initially_labeled.pdf')
    pp.savefig()
    pp.close()
    #plt.show()

# %%
import matplotlib.font_manager as font_manager
font_prop = font_manager.FontProperties(size=15)
font = {
        'size': 13,
        }

# %%
for i in range(len(percent_initially_unlabelled)):
    # %matplotlib inline
    plt.errorbar(disp_oSBM_array,
               [j[i] for j in MV1_results],
                 yerr=[j[i] for j in MV1_se_results], 
                 fmt='--o', capthick=2,
            #alpha=0.6, 
                 elinewidth=3, color = 'red')
    plt.text(0.000001,0.95,'1hop MV', color = 'red',  fontdict=font)
    plt.text(0.000001,0.89,'2hop MV', color = 'maroon', fontdict=font)


    plt.errorbar(disp_oSBM_array,
               [j[i] for j in MV2_results], 
                 yerr=[j[i] for j in MV2_se_results], 
                 fmt='--o', capthick=2,
            #alpha=0.6, 
                 elinewidth=3,color = 'maroon') 
    #plt.xlabel('dispersion')
    #plt.xlabel('$\phi^*_{in}$, $\phi^*_{out}$')
    #plt.text(0.0016, -0.15, '$\phi^*_{in}$, $\phi^*_{out}$', fontproperties=font_prop)
    plt.text(0.0013, -0.14, 'overdispersion', fontproperties=font_prop)


    plt.ylabel('AUC')
    plt.ylim(0,1.01)
    plt.xlim(np.min(disp_oSBM_array)-0.0001,np.max(disp_oSBM_array)+0.0001)
    #plt.set_spines["right"].set_visible(False)
    #plt.set_spines["top"].set_visible(False)
    plt.title(np.str((percent_initially_labelled[i] * 100)) + '% initially labeled')
    #plt.tight_layout()
    pp = PdfPages(dir_osbm +np.str((percent_initially_labelled[i] * 100)) + '_with_bars_initially_labeled.pdf')
    pp.savefig()
    pp.close()
    #plt.show()
